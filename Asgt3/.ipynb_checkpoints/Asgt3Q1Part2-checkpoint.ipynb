# %% [markdown]
# ## NYC Collision Analysis - Part 2

# %% [markdown]
# ### For each borough, find out distribution of collision scale. (One car involved? Two? Three? or more?) (From 2015 to present)

# %%
import numpy as np
import pandas as pd
import os
import datetime

# %%
# Read collision data from csv into a dataframe
df = pd.read_csv('Data/vehicle_collisions.csv', index_col = 3) 
df.head()
# Out:
#           UNIQUE KEY    DATE  TIME  ZIP CODE   LATITUDE  LONGITUDE  \
# BOROUGH
# QUEENS       3146911  1/1/15  0:20   11358.0  40.751847 -73.787862
# NaN          3146180  1/1/15  0:20       NaN  40.771289 -73.946693
# BROOKLYN     3146384  1/1/15  0:21   11205.0  40.689445 -73.955121
# BROOKLYN     3146013  1/1/15  0:30   11213.0  40.673845 -73.925080
# NaN          3146120  1/1/15  0:33       NaN        NaN        NaN
#
#                            LOCATION    ON STREET NAME   CROSS STREET NAME  \
# BOROUGH
# QUEENS     (40.7518471, -73.787862)         47 AVENUE          193 STREET
# NaN       (40.7712888, -73.9466928)               NaN                 NaN
# BROOKLYN  (40.6894449, -73.9551212)    BEDFORD AVENUE    LAFAYETTE AVENUE
# BROOKLYN  (40.6738445, -73.9250801)    BUFFALO AVENUE  SAINT MARKS AVENUE
# NaN                             NaN  RICHMOND TERRACE        SOUTH AVENUE
#
#          OFF STREET NAME       ...                      VEHICLE 1 TYPE  \
# BOROUGH                        ...
# QUEENS               NaN       ...         SPORT UTILITY/STATION WAGON
# NaN                  NaN       ...                   PASSENGER VEHICLE
# BROOKLYN             NaN       ...                   PASSENGER VEHICLE
# BROOKLYN             NaN       ...                                 BUS
# NaN                  NaN       ...                             UNKNOWN
#
#              VEHICLE 2 TYPE  VEHICLE 3 TYPE  VEHICLE 4 TYPE  VEHICLE 5 TYPE  \
# BOROUGH
# QUEENS                  NaN             NaN             NaN             NaN
# NaN                     NaN             NaN             NaN             NaN
# BROOKLYN            UNKNOWN             NaN             NaN             NaN
# BROOKLYN  PASSENGER VEHICLE             NaN             NaN             NaN
# NaN       PASSENGER VEHICLE             NaN             NaN             NaN
#
#                      VEHICLE 1 FACTOR  VEHICLE 2 FACTOR  VEHICLE 3 FACTOR  \
# BOROUGH
# QUEENS    TRAFFIC CONTROL DISREGARDED               NaN               NaN
# NaN                    ANIMALS ACTION               NaN               NaN
# BROOKLYN              FATIGUED/DROWSY       UNSPECIFIED               NaN
# BROOKLYN           LOST CONSCIOUSNESS               NaN               NaN
# NaN                       UNSPECIFIED       UNSPECIFIED               NaN
#
#          VEHICLE 4 FACTOR VEHICLE 5 FACTOR
# BOROUGH
# QUEENS                NaN              NaN
# NaN                   NaN              NaN
# BROOKLYN              NaN              NaN
# BROOKLYN              NaN              NaN
# NaN                   NaN              NaN
#
# [5 rows x 28 columns]

# %%
# Creating dataframe with relevant columns conaining the Boroughs and the vehicles involved during collisions for each borough.
df = df[['VEHICLE 1 TYPE', 'VEHICLE 2 TYPE', 'VEHICLE 3 TYPE', 'VEHICLE 4 TYPE', 'VEHICLE 5 TYPE']]
df.head()
# Out:
#                        VEHICLE 1 TYPE     VEHICLE 2 TYPE VEHICLE 3 TYPE  \
# BOROUGH
# QUEENS    SPORT UTILITY/STATION WAGON                NaN            NaN
# NaN                 PASSENGER VEHICLE                NaN            NaN
# BROOKLYN            PASSENGER VEHICLE            UNKNOWN            NaN
# BROOKLYN                          BUS  PASSENGER VEHICLE            NaN
# NaN                           UNKNOWN  PASSENGER VEHICLE            NaN
#
#          VEHICLE 4 TYPE VEHICLE 5 TYPE
# BOROUGH
# QUEENS              NaN            NaN
# NaN                 NaN            NaN
# BROOKLYN            NaN            NaN
# BROOKLYN            NaN            NaN
# NaN                 NaN            NaN

# %%
# Summing up the number of vehicles for each row
df['TOTAL_VEHICLES'] = df.notnull().sum(axis=1)
df.head()
# Out:
#                        VEHICLE 1 TYPE     VEHICLE 2 TYPE VEHICLE 3 TYPE  \
# BOROUGH
# QUEENS    SPORT UTILITY/STATION WAGON                NaN            NaN
# NaN                 PASSENGER VEHICLE                NaN            NaN
# BROOKLYN            PASSENGER VEHICLE            UNKNOWN            NaN
# BROOKLYN                          BUS  PASSENGER VEHICLE            NaN
# NaN                           UNKNOWN  PASSENGER VEHICLE            NaN
#
#          VEHICLE 4 TYPE VEHICLE 5 TYPE  TOTAL_VEHICLES
# BOROUGH
# QUEENS              NaN            NaN               1
# NaN                 NaN            NaN               1
# BROOKLYN            NaN            NaN               2
# BROOKLYN            NaN            NaN               2
# NaN                 NaN            NaN               2

# %%
df = df.reset_index()[['BOROUGH','TOTAL_VEHICLES']]
df.head()
# Out:
#     BOROUGH  TOTAL_VEHICLES
# 0    QUEENS               1
# 1       NaN               1
# 2  BROOKLYN               2
# 3  BROOKLYN               2
# 4       NaN               2

# %%
# Creating a pivot table to aggregate the number of collisions for each borough with respect to number of vehicles involved
df = df.pivot_table(index='BOROUGH', columns='TOTAL_VEHICLES', aggfunc=len, fill_value=0)
df = df.rename(index=str, columns={0:"NO_VEHICLE_INVOLVED", 1:"ONE_VEHICLE_INVOLVED", 2:"TWO_VEHICLES_INVOLVED", 3:"THREE_VEHICLES_INVOLVED",4:"FOUR_VEHICLES_INVOLVED",5:"FIVE_VEHICLES_INVOLVED"})

# %%
df
# Out:
# TOTAL_VEHICLES  NO_VEHICLE_INVOLVED  ONE_VEHICLE_INVOLVED  \
# BOROUGH
# BRONX                           525                  8627
# BROOKLYN                        787                 17375
# MANHATTAN                       801                 13318
# QUEENS                          515                 12962
# STATEN ISLAND                   105                  2343
#
# TOTAL_VEHICLES  TWO_VEHICLES_INVOLVED  THREE_VEHICLES_INVOLVED  \
# BOROUGH
# BRONX                           34385                     1962
# BROOKLYN                        80207                     4980
# MANHATTAN                       66958                     2024
# QUEENS                          70260                     4498
# STATEN ISLAND                   10676                      759
#
# TOTAL_VEHICLES  FOUR_VEHICLES_INVOLVED  FIVE_VEHICLES_INVOLVED
# BOROUGH
# BRONX                              452                     173
# BROOKLYN                          1151                     461
# MANHATTAN                          372                     129
# QUEENS                            1106                     314
# STATEN ISLAND                      133                      32

# %%
os.makedirs('Output', exist_ok=True)

# %%
df.to_csv('Output/Q1Part2.csv')

# %%
print('Completed the analysis for calculating the distribution of collision scale to show the number of vehicles involved for each collision on each borough. Output is saved as a csv file in the location Output/Q1Part2.csv')
# Out:
# Completed the analysis for calculating the distribution of collision scale to show the number of vehicles involved for each collision on each borough. Output is saved as a csv file in the location Output/Q1Part2.csv
