# %% [markdown]
# ## Analysis 2: Analysing the level of vendor competition in Govt. contracts

# %%
# %matplotlib inline

# %%
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ### Reading into dataframe from saved pickle file

# %%
pickle_df = pd.read_pickle('../Extra/us_spending_df.pickle')
pickle_df.head()
# Out:
#                           AgencyID AwardType  \
# 2016_MA_0_1  9700: DEPT OF DEFENSE         1
# 2016_MA_0_2  9700: DEPT OF DEFENSE         1
# 2016_MA_0_3  9700: DEPT OF DEFENSE         1
# 2016_MA_0_4  9700: DEPT OF DEFENSE         1
# 2016_MA_0_5  9700: DEPT OF DEFENSE         1
#
#                                            ContractDescription  \
# 2016_MA_0_1  FMS AND US AEGIS PRODUCTION (FCS AND SPY TRANS...
# 2016_MA_0_2  MODERNIZATION OF SIX PATRIOT FIRE UNITS FOR TH...
# 2016_MA_0_3                                       DDG 1002 MSE
# 2016_MA_0_4          QATAR ADOC CONTRACT #2 UCA DEFINITIZATION
# 2016_MA_0_5                       ADDITIONAL F414 FY15 ENGINES
#
#             ContractPricing            ContractingAgency  \
# 2016_MA_0_1               Y       1700: DEPT OF THE NAVY
# 2016_MA_0_2               Y       2100: DEPT OF THE ARMY
# 2016_MA_0_3               Y       1700: DEPT OF THE NAVY
# 2016_MA_0_4               Y  5700: DEPT OF THE AIR FORCE
# 2016_MA_0_5               N       1700: DEPT OF THE NAVY
#
#             ContractingAgencyCode DUNSNumber               DateSigned  \
# 2016_MA_0_1                  1700  193049236  2016-05-27T00:00:00.000
# 2016_MA_0_2                  2100  196882310  2016-06-23T00:00:00.000
# 2016_MA_0_3                  1700  184724797  2015-12-31T00:00:00.000
# 2016_MA_0_4                  5700  184724797  2015-10-16T00:00:00.000
# 2016_MA_0_5                  1700  001408509  2015-12-30T00:00:00.000
#
#             DollarsObligated ExtentCompeted            ...             \
# 2016_MA_0_1     3.658488E+08              C            ...
# 2016_MA_0_2        256459280              C            ...
# 2016_MA_0_3     2.552817E+08              C            ...
# 2016_MA_0_4        142685024              B            ...
# 2016_MA_0_5        121208608              C            ...
#
#                         RecipientName RecipientOrContractorName  \
# 2016_MA_0_1          RAYTHEON COMPANY          RAYTHEON COMPANY
# 2016_MA_0_2          RAYTHEON COMPANY          RAYTHEON COMPANY
# 2016_MA_0_3          RAYTHEON COMPANY          RAYTHEON COMPANY
# 2016_MA_0_4          RAYTHEON COMPANY          RAYTHEON COMPANY
# 2016_MA_0_5  GENERAL ELECTRIC COMPANY  GENERAL ELECTRIC COMPANY
#
#             RecipientState RecipientZipCode TransactionNumber  \
# 2016_MA_0_1             MA            01752                 0
# 2016_MA_0_2             MA            01810                 2
# 2016_MA_0_3             MA            01876                 0
# 2016_MA_0_4             MA            01876                14
# 2016_MA_0_5             MA            01905                 0
#
#             TransactionStatus TypeofSpending TypeofTransaction  \
# 2016_MA_0_1                 F              C                 F
# 2016_MA_0_2                 F              C                 F
# 2016_MA_0_3                 F              C                 F
# 2016_MA_0_4                 F              C                 F
# 2016_MA_0_5                 F              C                 F
#
#             UniqueTransactionID                VendorName
# 2016_MA_0_1                   0          RAYTHEON COMPANY
# 2016_MA_0_2                   2          RAYTHEON COMPANY
# 2016_MA_0_3                   0          RAYTHEON COMPANY
# 2016_MA_0_4                  14          RAYTHEON COMPANY
# 2016_MA_0_5                   0  GENERAL ELECTRIC COMPANY
#
# [5 rows x 43 columns]

# %% [markdown]
# ### Displaying all the columns of dataframe pickle_df

# %%
pickle_df.columns
# Out:
# Index(['AgencyID', 'AwardType', 'ContractDescription', 'ContractPricing',
#        'ContractingAgency', 'ContractingAgencyCode', 'DUNSNumber',
#        'DateSigned', 'DollarsObligated', 'ExtentCompeted', 'FiscalYear',
#        'FundingAgency', 'IDVAgency', 'IDVProcurementInstrumentID',
#        'MajorAgency', 'MajorFundingAgency', 'ModificationNumber',
#        'PSCCategoryCode', 'ParentRecipientOrCompanyName',
#        'PlaceofPerformanceCongDistrict', 'PlaceofPerformanceState',
#        'PlaceofPerformanceZipCode', 'PrincipalNAICSCode',
#        'PrincipalPlaceCountyOrCity', 'ProcurementInstrumentID',
#        'ProductorServiceCode', 'ProgramSource', 'ProgramSourceAccountCode',
#        'ProgramSourceAgencyCode', 'ReasonForModification',
#        'RecipientAddressLine123', 'RecipientCity',
#        'RecipientCongressionalDistrict', 'RecipientName',
#        'RecipientOrContractorName', 'RecipientState', 'RecipientZipCode',
#        'TransactionNumber', 'TransactionStatus', 'TypeofSpending',
#        'TypeofTransaction', 'UniqueTransactionID', 'VendorName'],
#       dtype='object')

# %% [markdown]
# ### Filter out rows that don't have value for column 'Extent Competed'

# %%
pickle_df = pickle_df[pickle_df['ExtentCompeted'].notnull()]

# %%
pickle_df['ExtentCompeted'].unique()
# Out:
# array(['C', 'B', 'D', 'A', 'F', 'CDO', 'G', 'NDO', 'E'], dtype=object)

# %% [markdown]
# ### Define categories and order for Extent Competed in increasing order of openness

# %%
pickle_df['ExtentCompeted'] = pickle_df['ExtentCompeted'].astype('category',categories=['G','C','B','D','CDO','F','A'], ordered = True)

# %%
pickle_df.describe()
# Out:
#                      AgencyID AwardType ContractDescription ContractPricing  \
# count                  704528    704528              704528          569121
# unique                    134         1              654600               3
# top     9700: DEPT OF DEFENSE         1        IGF::OT::IGF               N
# freq                   635355    704528                1298          560741
#
#                      ContractingAgency ContractingAgencyCode DUNSNumber  \
# count                           704528                704528     704528
# unique                             147                   139      12481
# top     97AS: DEFENSE LOGISTICS AGENCY                  97AS  007914906
# freq                            599603                599603     383774
#
#                      DateSigned DollarsObligated ExtentCompeted  \
# count                    704528           704528         704496
# unique                      568           352276              7
# top     2016-04-13T00:00:00.000                0              A
# freq                       4097            16171         552189
#
#                        ...                  \
# count                  ...
# unique                 ...
# top                    ...
# freq                   ...
#
#                              RecipientName  \
# count                               704528
# unique                               12968
# top     AMERISOURCEBERGEN DRUG CORPORATION
# freq                                383764
#
#                  RecipientOrContractorName RecipientState RecipientZipCode  \
# count                               704528         704373           704506
# unique                               12968             80             4219
# top     AMERISOURCEBERGEN DRUG CORPORATION             PA            19087
# freq                                383764         603158           387667
#
#        TransactionNumber TransactionStatus TypeofSpending TypeofTransaction  \
# count             704528            704528         704528            704528
# unique                17                 1              1                 1
# top                    0                 F              C                 F
# freq              698708            704528         704528            704528
#
#        UniqueTransactionID                          VendorName
# count               704528                              704528
# unique                  17                               12968
# top                      0  AMERISOURCEBERGEN DRUG CORPORATION
# freq                698708                              383764
#
# [4 rows x 43 columns]

# %% [markdown]
# ### Group by ExtentCompeted

# %%
pickle_df['DollarsObligated'] = pickle_df['DollarsObligated'].apply(pd.to_numeric)
grouped = pickle_df.groupby('ExtentCompeted').agg({'DollarsObligated':np.mean, 'DateSigned':'count'})
grouped = grouped.rename(index=str, columns={'DateSigned':'ContractCount'})
grouped
# Out:
#                 ContractCount  DollarsObligated
# ExtentCompeted
# G                       18412      21376.431879
# C                       19393     755863.605133
# B                        4829     255083.963093
# D                       11678     243997.725630
# CDO                       110     894950.788882
# F                       97885      12565.271772
# A                      552189      33166.829701

# %% [markdown]
# ### Plot grouped data to show the 'average amount' of DollarsObligated under each category of contract competition openness

# %%
fig = plt.figure()
ax = plt.subplot(111)
colors = [ '#00E28E','#00C69C','#00AAAA','#008DB8','#0071C6','#0055D4','#0038E2']
explode = [0.2,0.3,0.4,0,0,0,0]
grouped_sorted = grouped['DollarsObligated'].copy()
grouped_sorted.sort()
plt.axis('equal')
grouped_sorted.plot(kind='pie', ax=ax,  fontsize=10, explode=explode, colors=colors)

plt.savefig('Analysis2/CompetitionOpennessDistribution.png')
# Out:
# C:\Users\parit\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting

# %% [markdown]
# ### Conclusion: In the ExtentCompeted category 'C', there's a lot of money spent but these contracts are not open for competition. Thus, these companies benefit from a monopoly situation.

# %%
pickle_df_filtered = pickle_df[pickle_df['ExtentCompeted']=='C']
company_list = pickle_df_filtered['ParentRecipientOrCompanyName'].values

# %%
def drawWordCloud(text):
    other_stopwords = list(STOPWORDS) + ['INC', 'CORPORATION', 'COMPANY', 'nan']
    wc = WordCloud(background_color="white", max_words=2000, stopwords=set(other_stopwords)).generate(' '.join(str(v) for v in text))
    plt.imshow(wc)
    plt.axis("off")
    plt.show()
    wc.to_file('Analysis2/Wordcloud.png')

# %%
drawWordCloud(company_list)

# %% [markdown]
# ### Conclusion: The above wordcloud highlights the names of the companies that operate with benefits of a monopoly
